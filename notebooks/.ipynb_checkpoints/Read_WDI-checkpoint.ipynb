# %%
import pandas as pd

# %%
WDI_df = pd.read_excel('../data/WDIEXCEL.xlsx')

# %%
WDI_df.T
# Out:
#                                                            0       \
# Country Name                                           Arab World
# Country Code                                                  ARB
# Indicator Name  Access to clean fuels and technologies for coo...
# Indicator Code                                     EG.CFT.ACCS.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2015                                                      84.1716
# 2016                                                      84.5102
# 2017                                                          NaN
# 2018                                                          NaN
# 2019                                                          NaN
#
#                                                  1       \
# Country Name                                 Arab World
# Country Code                                        ARB
# ...

# %%
WDI_df.to_pickle('../data/pickles/WDI_full.pkl')

# %%
df = pd.read_pickle('../data/pickles/WDI_full.pkl')
